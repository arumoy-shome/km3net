# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import random
from context import km3net
import km3net.data.utils as utils
from km3net.utils import DATADIR

# %%
hits = pd.read_csv("../data/hits.csv")
hits = hits.sort_values(by=['time'])
hits
# Out:
#         dom_id  pmt_id   pos_x    pos_y    pos_z  dir_x  dir_y  dir_z  tot  \
# 325995    1054   32658 -16.064  -76.599  112.441  0.000  0.955 -0.296   35
# 325997    1054   32671 -16.208  -76.707  112.611 -0.719  0.415  0.558   24
# 325992    1053   32639 -16.064  -76.624  122.011  0.000  0.830  0.558   12
# 325996    1054   32670 -16.064  -76.624  112.611  0.000  0.830  0.558   54
# 325998    1054   32664 -15.968  -76.625  112.559  0.478  0.827  0.296   47
# ...        ...     ...     ...      ...      ...    ...    ...    ...  ...
# 239871    2016   62496  88.433  -60.180   38.011  0.719 -0.415  0.558   23
# 239869    1953   60527  30.897  -58.959  121.841  0.000  0.955 -0.296   26
# 238077    1673   51848  61.686  101.731   47.241 -0.827  0.478 -0.296   25
# 238075    1566   48536  40.629   67.440   37.959  0.478  0.827  0.296   29
# 238076    1638   50751  30.952   86.327   37.731 -0.460  0.266 -0.847   29
#
#               time  label
# 325995     28449.0      1
# 325997     28450.0      1
# 325992     28450.0      1
# 325996     28450.0      1
# 325998     28451.0      1
# ...            ...    ...
# 239871  99980920.0      1
# 239869  99981723.0      1
# 238077  99985448.0      1
# 238075  99985904.0      1
# 238076  99986011.0      1
#
# [489906 rows x 11 columns]

# %% [markdown]
# # Load the data

# %%
slices = list(range(0, 10000000, 15000))

timeslices = []
while len(timeslices) < 10:
    choice = random.choice(slices)
    if choice < slices[-1]:
        timeslices.append((choice, choice+15000))

timeslices
# Out:
# [(5340000, 5355000),
#  (4530000, 4545000),
#  (9645000, 9660000),
#  (9585000, 9600000),
#  (9870000, 9885000),
#  (4290000, 4305000),
#  (7560000, 7575000),
#  (3120000, 3135000),
#  (7050000, 7065000),
#  (570000, 585000)]

# %%
fig, axs = plt.subplots(5, 2, figsize=(15, 15))

# plot 1
timeslices_idx = 0
slice = hits[(hits.time >= timeslices[timeslices_idx][0]) & (hits.time < timeslices[timeslices_idx][1])]
axs[0, 0].scatter(slice.time, slice.pos_x)

# plot 2
timeslices_idx = 1
slice = hits[(hits.time >= timeslices[timeslices_idx][0]) & (hits.time < timeslices[timeslices_idx][1])]
axs[0, 1].scatter(slice.time, slice.pos_x)

# plot 3
timeslices_idx = 2
slice = hits[(hits.time >= timeslices[timeslices_idx][0]) & (hits.time < timeslices[timeslices_idx][1])]
axs[1, 0].scatter(slice.time, slice.pos_x)

# plot 4
timeslices_idx = 3
slice = hits[(hits.time >= timeslices[timeslices_idx][0]) & (hits.time < timeslices[timeslices_idx][1])]
axs[1, 1].scatter(slice.time, slice.pos_x)

# plot 5
timeslices_idx = 4
slice = hits[(hits.time >= timeslices[timeslices_idx][0]) & (hits.time < timeslices[timeslices_idx][1])]
axs[2, 0].scatter(slice.time, slice.pos_x)
    
# plot 6
timeslices_idx = 5
slice = hits[(hits.time >= timeslices[timeslices_idx][0]) & (hits.time < timeslices[timeslices_idx][1])]
axs[2, 1].scatter(slice.time, slice.pos_x)

# plot 7
timeslices_idx = 6
slice = hits[(hits.time >= timeslices[timeslices_idx][0]) & (hits.time < timeslices[timeslices_idx][1])]
axs[3, 0].scatter(slice.time, slice.pos_x)

# plot 8
timeslices_idx = 7
slice = hits[(hits.time >= timeslices[timeslices_idx][0]) & (hits.time < timeslices[timeslices_idx][1])]
axs[3, 1].scatter(slice.time, slice.pos_x)

# plot 9
timeslices_idx = 8
slice = hits[(hits.time >= timeslices[timeslices_idx][0]) & (hits.time < timeslices[timeslices_idx][1])]
axs[4, 0].scatter(slice.time, slice.pos_x)

# plot 10
timeslices_idx = 9
slice = hits[(hits.time >= timeslices[timeslices_idx][0]) & (hits.time < timeslices[timeslices_idx][1])]
axs[4, 1].scatter(slice.time, slice.pos_x)

# %% [markdown]
# # Additional verification
#
# Based on the progress meeting on July 16, 2020 the following verification strategy was followed:
# - look at the distribution of the

# %%
df = utils.load(DATADIR+'/processed/data.csv')
df
# Out:
#            pos_x   pos_y    pos_z         time  label  event_id  timeslice
# 0        -17.661  32.245   65.231          0.0      0       NaN          0
# 1         76.840 -77.173  186.931          0.0      0       NaN          0
# 2        -73.403  30.509   94.511          0.0      0       NaN          0
# 3          1.453  33.155  169.111          0.0      0       NaN          0
# 4         49.456  47.904  140.111          0.0      0       NaN          0
# ...          ...     ...      ...          ...    ...       ...        ...
# 45820211 -57.230  -5.401  196.389  101502104.0      0       NaN       6766
# 45820212   0.724  66.341  121.789  101516467.0      0       NaN       6767
# 45820213 -26.436  86.737  160.131  101545421.0      0       NaN       6769
# 45820214 -26.931 -21.994  178.511  101581891.0      0       NaN       6772
# 45820215  77.823 -40.053   65.341  101591357.0      0       NaN       6772
#
# [45820216 rows x 7 columns]

# %%
df_by_event_id = df.groupby('event_id').mean()
df_by_event_id
# Out:
#               pos_x       pos_y       pos_z          time  label  timeslice
# event_id
# 0.0      -59.423800   74.030000  140.774200  2.728731e+07    1.0     1819.0
# 1.0        2.530000  104.211000  121.731000  6.671443e+07    1.0     4447.0
# 2.0      -13.767400   60.047200  106.694200  7.325907e+07    1.0     4883.0
# 3.0       16.854500   77.011250  166.347000  4.596669e+07    1.0     3064.0
# 4.0       -2.100000  -87.249000  140.581000  4.332858e+07    1.0     2888.0
# ...             ...         ...         ...           ...    ...        ...
# 5730.0   -84.486500   13.002500  169.461000  2.147557e+07    1.0     1431.0
# 5731.0    38.650818   77.647428  170.093213  3.727547e+07    1.0     2485.0
# 5732.0    15.097667    7.337667  153.297667  2.313434e+07    1.0     1542.0
# 5733.0   -66.844208   45.541610   69.377065  9.914732e+07    1.0     6609.0
# 5734.0    58.772222  -43.442111  132.229222  7.205646e+07    1.0     4803.0
#
# [5715 rows x 6 columns]

# %%
plt.scatter(df_by_event_id.index, df_by_event_id['time'])
